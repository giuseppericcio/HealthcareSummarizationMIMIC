# %% [markdown]
# # Named Entity Recognition

# %% [markdown]
# ## Librerie Utili

# %%
import pandas as pd

from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

from medcat.cat import CAT
from medcat.cdb import CDB
from medcat.vocab import Vocab
from medcat.meta_cat import MetaCAT

# %% [markdown]
# ## Lettura del NOTEEVENTS preprocessato

# %%
data = pd.read_csv("preprocessed_noteevents.csv", sep=";", header=0)
data.head(5)
# Out:
#    ROW_ID  SUBJECT_ID   CHARTDATE  \
# 0     722       27431  2148-03-07
# 1     723       27431  2148-03-29
# 2     724       27431  2148-04-08
# 3    1907       21323  2139-05-04
# 4    1905       21323  2135-08-06
#
#                                                 TEXT GENDER  \
# 0  Admission Date:  [**2148-3-2**]              D...      M
# 1  Admission Date:  [**2148-3-20**]              ...      M
# 2  Admission Date:  [**2148-4-8**]              D...      M
# 3  Admission Date:  [**2139-4-26**]              ...      M
# 4  Admission Date:  [**2135-7-30**]     Discharge...      M
#
#                    DOB                  DOD  EXPIRE_FLAG  \
# 0  2070-10-04 00:00:00  2148-04-08 00:00:00            1
# 1  2070-10-04 00:00:00  2148-04-08 00:00:00            1
# 2  2070-10-04 00:00:00  2148-04-08 00:00:00            1
# 3  2082-12-21 00:00:00                  NaN            0
# 4  2082-12-21 00:00:00                  NaN            0
#
#                                      LEMMATIZED TEXT  TOKEN_COUNT_COMP
# 0  Chief Complaint Hypotension/hypoxia Major Surg...           1005.25
# 1  Chief Complaint Hypoxia Major Surgical Invasiv...           1676.50
# 2  Chief Complaint hypoxia s/p PEA arrest Major S...            379.75
# 3  Chief Complaint black stool Major Surgical Inv...            504.00
# 4  HISTORY PRESENT ILLNESS Patient 52-year-old ma...            561.25

# %% [markdown]
# ## Modelli NER Hugging Face

# %% [markdown]
# ### Modello Taught Net

# %%
tokenizer = AutoTokenizer.from_pretrained("marcopost-it/TaughtNet-disease-chem-gene")
model = AutoModelForTokenClassification.from_pretrained("marcopost-it/TaughtNet-disease-chem-gene")
pipe = pipeline("ner", tokenizer=tokenizer, model=model, aggregation_strategy='first')

# %%
tokenizer.model_max_length = 512

# %%
ner = pipe(data['TEXT'][0])

for entity in ner:
    print(entity)
# Out:
# {'entity_group': 'disease', 'score': 0.2921802, 'word': ' schizophrenia,', 'start': 446, 'end': 460}
# {'entity_group': 'disease', 'score': 0.26068684, 'word': ' CAD,', 'start': 461, 'end': 465}
# {'entity_group': 'disease', 'score': 0.25280395, 'word': ' HTN,', 'start': 466, 'end': 470}
# {'entity_group': 'disease', 'score': 0.296749, 'word': ' dementia', 'start': 471, 'end': 479}
# {'entity_group': 'disease', 'score': 0.30921772, 'word': ' FTT', 'start': 496, 'end': 499}
# {'entity_group': 'chem', 'score': 0.30997872, 'word': ' CTX.\nSubsequently,', 'start': 849, 'end': 867}
# {'entity_group': 'disease', 'score': 0.23614524, 'word': ' diarrhea.', 'start': 1119, 'end': 1128}
# {'entity_group': 'chem', 'score': 0.31843758, 'word': ' Levaquin', 'start': 1427, 'end': 1435}
# {'entity_group': 'chem', 'score': 0.30741656, 'word': ' FLagyl', 'start': 1440, 'end': 1446}
# {'entity_group': 'disease', 'score': 0.24316074, 'word': ' aspiration PNA\nalthough', 'start': 1460, 'end': 1483}
# c:\Users\giuse\Desktop\Progetto Finale\healthcare\lib\site-packages\transformers\pipelines\token_classification.py:393: UserWarning: Tokenizer does not support real words, using fallback heuristic
#   warnings.warn(

# %%
ner = pipe(data['LEMMATIZED TEXT'][0])

for entity in ner:
    print(entity)
# Out:
# {'entity_group': 'disease', 'score': 0.29073653, 'word': ' Hypotension/hypoxia', 'start': 16, 'end': 35}
# {'entity_group': 'disease', 'score': 0.30189118, 'word': ' schizophrenia', 'start': 163, 'end': 176}
# {'entity_group': 'disease', 'score': 0.28751686, 'word': ' CAD', 'start': 177, 'end': 180}
# {'entity_group': 'disease', 'score': 0.25589857, 'word': ' HTN dementia', 'start': 181, 'end': 193}
# {'entity_group': 'disease', 'score': 0.25982344, 'word': ' hypoxia', 'start': 198, 'end': 205}
# {'entity_group': 'disease', 'score': 0.23587082, 'word': ' FTT', 'start': 206, 'end': 209}
# {'entity_group': 'chem', 'score': 0.31625417, 'word': ' levaquin', 'start': 405, 'end': 413}
# {'entity_group': 'chem', 'score': 0.29079407, 'word': ' CTX', 'start': 447, 'end': 450}
# {'entity_group': 'disease', 'score': 0.23271823, 'word': ' cough', 'start': 628, 'end': 633}
# {'entity_group': 'disease', 'score': 0.2406837, 'word': ' diarrhea', 'start': 634, 'end': 642}
# {'entity_group': 'disease', 'score': 0.22855523, 'word': ' SOB', 'start': 643, 'end': 646}
# {'entity_group': 'chem', 'score': 0.3097743, 'word': ' Vancomycin', 'start': 831, 'end': 841}
# {'entity_group': 'chem', 'score': 0.31138164, 'word': ' Levaquin', 'start': 842, 'end': 850}
# {'entity_group': 'chem', 'score': 0.22842929, 'word': ' FLagyl', 'start': 851, 'end': 857}
# {'entity_group': 'disease', 'score': 0.26053992, 'word': ' aspiration', 'start': 867, 'end': 877}
# {'entity_group': 'disease', 'score': 0.29684296, 'word': ' Schizophrenia', 'start': 1268, 'end': 1281}
# {'entity_group': 'disease', 'score': 0.27771172, 'word': ' Depression', 'start': 1326, 'end': 1336}
# {'entity_group': 'disease', 'score': 0.27037087, 'word': ' HTN', 'start': 1337, 'end': 1340}
# {'entity_group': 'disease', 'score': 0.295094, 'word': ' Dementia', 'start': 1341, 'end': 1349}
# {'entity_group': 'disease', 'score': 0.23156828, 'word': ' R', 'start': 1350, 'end': 1351}
# {'entity_group': 'disease', 'score': 0.19539225, 'word': ' cataract', 'start': 1356, 'end': 1364}
# {'entity_group': 'disease', 'score': 0.24503745, 'word': ' CAD', 'start': 1365, 'end': 1368}
# {'entity_group': 'chem', 'score': 0.28424814, 'word': ' fluconazole', 'start': 1978, 'end': 1989}
# {'entity_group': 'disease', 'score': 0.2738517, 'word': ' oral thrush', 'start': 1990, 'end': 2001}
# {'entity_group': 'chem', 'score': 0.23430714, 'word': ' Nystatin', 'start': 2015, 'end': 2023}
# {'entity_group': 'disease', 'score': 0.27465808, 'word': ' osteomyelitis', 'start': 2053, 'end': 2066}
# {'entity_group': 'disease', 'score': 0.30148548, 'word': ' osteomyelitis', 'start': 2107, 'end': 2120}
# {'entity_group': 'disease', 'score': 0.29349887, 'word': ' myocardial infarction', 'start': 2336, 'end': 2357}
# {'entity_group': 'disease', 'score': 0.25644097, 'word': ' anterior', 'start': 2406, 'end': 2414}
# {'entity_group': 'disease', 'score': 0.24094403, 'word': ' symmetric', 'start': 2472, 'end': 2481}
# {'entity_group': 'disease', 'score': 0.27461037, 'word': ' left ventricular hypertrophy', 'start': 2482, 'end': 2510}
# {'entity_group': 'disease', 'score': 0.28661978, 'word': ' left ventricular systolic dysfunction', 'start': 2553, 'end': 2590}
# {'entity_group': 'disease', 'score': 0.2596153, 'word': ' hypokinesis/akinesis', 'start': 2598, 'end': 2618}

# %% [markdown]
# ### Modello Bert Clinical NER

# %%
tokenizer2 = AutoTokenizer.from_pretrained("samrawal/bert-base-uncased_clinical-ner")
model2 = AutoModelForTokenClassification.from_pretrained("samrawal/bert-base-uncased_clinical-ner")
pipe2 = pipeline("ner", tokenizer=tokenizer2, model=model2, aggregation_strategy='first')

# %%
ner2 = pipe2(data['TEXT'][0])

for entity2 in ner2:
    print(entity2)
# Out:
# {'entity_group': 'problem', 'score': 0.9958555, 'word': 'known allergies', 'start': 193, 'end': 208}
# {'entity_group': 'problem', 'score': 0.99867237, 'word': 'hypotension', 'start': 281, 'end': 292}
# {'entity_group': 'problem', 'score': 0.9961487, 'word': 'hypoxia', 'start': 293, 'end': 300}
# {'entity_group': 'treatment', 'score': 0.9305995, 'word': 'dobhoff tube', 'start': 353, 'end': 365}
# {'entity_group': 'treatment', 'score': 0.76258314, 'word': 'arterial line', 'start': 379, 'end': 392}
# {'entity_group': 'problem', 'score': 0.9971476, 'word': 'schizophrenia', 'start': 446, 'end': 459}
# {'entity_group': 'problem', 'score': 0.9967463, 'word': 'cad', 'start': 461, 'end': 464}
# {'entity_group': 'problem', 'score': 0.99339914, 'word': 'htn', 'start': 466, 'end': 469}
# {'entity_group': 'problem', 'score': 0.9948183, 'word': 'dementia', 'start': 471, 'end': 479}
# {'entity_group': 'problem', 'score': 0.9960675, 'word': 'hypoxia', 'start': 484, 'end': 491}
# {'entity_group': 'problem', 'score': 0.9787716, 'word': 'ftt', 'start': 496, 'end': 499}
# {'entity_group': 'problem', 'score': 0.9953998, 'word': 'desaturation', 'start': 559, 'end': 571}
# {'entity_group': 'treatment', 'score': 0.86875725, 'word': '2l nc', 'start': 629, 'end': 634}
# {'entity_group': 'problem', 'score': 0.88870835, 'word': 'decreased', 'start': 662, 'end': 671}
# {'entity_group': 'treatment', 'score': 0.99247944, 'word': 'ivf fluids', 'start': 737, 'end': 747}
# {'entity_group': 'test', 'score': 0.9963303, 'word': 'cxr', 'start': 760, 'end': 763}
# {'entity_group': 'test', 'score': 0.50828826, 'word': 'neg', 'start': 770, 'end': 773}
# {'entity_group': 'test', 'score': 0.94838196, 'word': 'ua', 'start': 775, 'end': 777}
# {'entity_group': 'treatment', 'score': 0.9986933, 'word': 'levaquin', 'start': 794, 'end': 802}
# {'entity_group': 'treatment', 'score': 0.8955616, 'word': 'ctx', 'start': 849, 'end': 852}
# {'entity_group': 'test', 'score': 0.8196596, 'word': 'ucx', 'start': 868, 'end': 871}
# {'entity_group': 'problem', 'score': 0.9972882, 'word': 'hypotensive', 'start': 932, 'end': 943}
# {'entity_group': 'problem', 'score': 0.9972765, 'word': 'hypoxic', 'start': 948, 'end': 955}
# {'entity_group': 'problem', 'score': 0.9979499, 'word': 'cough', 'start': 1112, 'end': 1117}
# {'entity_group': 'problem', 'score': 0.9965228, 'word': 'diarrhea', 'start': 1119, 'end': 1127}
# {'entity_group': 'problem', 'score': 0.994565, 'word': 'sob', 'start': 1131, 'end': 1134}
# {'entity_group': 'problem', 'score': 0.96913517, 'word': 'dizziness', 'start': 1138, 'end': 1147}
# {'entity_group': 'problem', 'score': 0.97838473, 'word': 'unreponsive', 'start': 1156, 'end': 1167}
# {'entity_group': 'test', 'score': 0.9391772, 'word': 'evaluation', 'start': 1192, 'end': 1202}
# {'entity_group': 'problem', 'score': 0.9968721, 'word': 'unresponsive', 'start': 1221, 'end': 1233}
# {'entity_group': 'test', 'score': 0.9844348, 'word': 'bp', 'start': 1247, 'end': 1249}
# {'entity_group': 'test', 'score': 0.7667045, 'word': 'hr', 'start': 1289, 'end': 1291}
# {'entity_group': 'test', 'score': 0.8833088, 'word': 'rr', 'start': 1296, 'end': 1298}
# {'entity_group': 'test', 'score': 0.9912271, 'word': 'o2sat', 'start': 1303, 'end': 1308}
# {'entity_group': 'treatment', 'score': 0.945315, 'word': 'a foley', 'start': 1347, 'end': 1354}
# {'entity_group': 'treatment', 'score': 0.9924495, 'word': 'empiric vancomycin', 'start': 1407, 'end': 1425}
# {'entity_group': 'treatment', 'score': 0.9984006, 'word': 'levaquin', 'start': 1427, 'end': 1435}
# {'entity_group': 'treatment', 'score': 0.9981065, 'word': 'flagyl', 'start': 1440, 'end': 1446}
# {'entity_group': 'problem', 'score': 0.996867, 'word': 'aspiration pna', 'start': 1460, 'end': 1474}
# {'entity_group': 'test', 'score': 0.99797064, 'word': 'cxr', 'start': 1484, 'end': 1487}
# {'entity_group': 'problem', 'score': 0.99321115, 'word': 'clear consolidation', 'start': 1498, 'end': 1517}
# {'entity_group': 'test', 'score': 0.97709924, 'word': 'ua', 'start': 1519, 'end': 1521}
# {'entity_group': 'test', 'score': 0.9928005, 'word': 'an ekg', 'start': 1549, 'end': 1555}
# {'entity_group': 'problem', 'score': 0.8699545, 'word': 'sr', 'start': 1577, 'end': 1579}
# {'entity_group': 'test', 'score': 0.8168479, 'word': 'hr', 'start': 1581, 'end': 1583}
# {'entity_group': 'problem', 'score': 0.48743775, 'word': 'na', 'start': 1588, 'end': 1590}
# {'entity_group': 'problem', 'score': 0.9593745, 'word': 'loss of rw in inferior leads', 'start': 1592, 'end': 1620}
# {'entity_group': 'problem', 'score': 0.59417254, 'word': 'v1', 'start': 1622, 'end': 1624}
# {'entity_group': 'problem', 'score': 0.6684119, 'word': 'v2', 'start': 1626, 'end': 1628}
# {'entity_group': 'problem', 'score': 0.9796341, 'word': 'ste', 'start': 1633, 'end': 1636}
# {'entity_group': 'test', 'score': 0.97779053, 'word': 'ce', 'start': 1669, 'end': 1671}
# {'entity_group': 'test', 'score': 0.987181, 'word': 'trop', 'start': 1693, 'end': 1697}
# {'entity_group': 'test', 'score': 0.97873265, 'word': 'ck', 'start': 1704, 'end': 1706}
# {'entity_group': 'test', 'score': 0.6820677, 'word': 'mb', 'start': 1712, 'end': 1714}

# %%
ner2 = pipe2(data['LEMMATIZED TEXT'][0])

for entity2 in ner2:
    print(entity2)
# Out:
# {'entity_group': 'problem', 'score': 0.99713194, 'word': 'hypotension', 'start': 16, 'end': 27}
# {'entity_group': 'problem', 'score': 0.9933426, 'word': 'hypoxia', 'start': 28, 'end': 35}
# {'entity_group': 'treatment', 'score': 0.95294684, 'word': 'major surgical invasive procedure placement', 'start': 36, 'end': 79}
# {'entity_group': 'treatment', 'score': 0.8965652, 'word': 'dobhoff tube placement', 'start': 80, 'end': 102}
# {'entity_group': 'treatment', 'score': 0.8915086, 'word': 'line', 'start': 112, 'end': 116}
# {'entity_group': 'problem', 'score': 0.9921606, 'word': 'schizophrenia', 'start': 163, 'end': 176}
# {'entity_group': 'problem', 'score': 0.92668873, 'word': 'cad', 'start': 177, 'end': 180}
# {'entity_group': 'problem', 'score': 0.9257811, 'word': 'htn', 'start': 181, 'end': 184}
# {'entity_group': 'problem', 'score': 0.9828106, 'word': 'dementia', 'start': 185, 'end': 193}
# {'entity_group': 'problem', 'score': 0.99694186, 'word': 'hypoxia', 'start': 198, 'end': 205}
# {'entity_group': 'test', 'score': 0.450036, 'word': 'ftt', 'start': 206, 'end': 209}
# {'entity_group': 'problem', 'score': 0.96033555, 'word': 'episode', 'start': 236, 'end': 243}
# {'entity_group': 'problem', 'score': 0.9079778, 'word': 'desaturation', 'start': 244, 'end': 256}
# {'entity_group': 'problem', 'score': 0.9295139, 'word': 'decreased', 'start': 311, 'end': 320}
# {'entity_group': 'treatment', 'score': 0.8758599, 'word': 'ivf fluid', 'start': 364, 'end': 373}
# {'entity_group': 'treatment', 'score': 0.9984964, 'word': 'levaquin', 'start': 405, 'end': 413}
# {'entity_group': 'problem', 'score': 0.9908762, 'word': 'hypotensive hypoxic', 'start': 512, 'end': 531}
# {'entity_group': 'problem', 'score': 0.90427893, 'word': 'cough', 'start': 628, 'end': 633}
# {'entity_group': 'problem', 'score': 0.97061634, 'word': 'diarrhea', 'start': 634, 'end': 642}
# {'entity_group': 'problem', 'score': 0.9646995, 'word': 'sob dizziness', 'start': 643, 'end': 656}
# {'entity_group': 'problem', 'score': 0.8676628, 'word': 'unreponsive', 'start': 657, 'end': 668}
# {'entity_group': 'test', 'score': 0.8805381, 'word': 'question evaluation', 'start': 669, 'end': 688}
# {'entity_group': 'problem', 'score': 0.86300004, 'word': 'unresponsive ed', 'start': 693, 'end': 708}
# {'entity_group': 'test', 'score': 0.9688334, 'word': 'bp', 'start': 709, 'end': 711}
# {'entity_group': 'test', 'score': 0.84245795, 'word': 'vs', 'start': 734, 'end': 736}
# {'entity_group': 'test', 'score': 0.95082295, 'word': 'hr', 'start': 737, 'end': 739}
# {'entity_group': 'test', 'score': 0.9773186, 'word': 'rr', 'start': 743, 'end': 745}
# {'entity_group': 'test', 'score': 0.9626403, 'word': 'o2sat', 'start': 749, 'end': 754}
# {'entity_group': 'test', 'score': 0.5197987, 'word': 'nrb', 'start': 759, 'end': 762}
# {'entity_group': 'test', 'score': 0.8242649, 'word': 'total', 'start': 772, 'end': 777}
# {'entity_group': 'test', 'score': 0.5078713, 'word': 'foley', 'start': 783, 'end': 788}
# {'entity_group': 'treatment', 'score': 0.6112186, 'word': 'placed', 'start': 789, 'end': 795}
# {'entity_group': 'treatment', 'score': 0.59979784, 'word': 'urinated', 'start': 796, 'end': 804}
# {'entity_group': 'treatment', 'score': 0.99457645, 'word': 'empiric', 'start': 823, 'end': 830}
# {'entity_group': 'treatment', 'score': 0.9360467, 'word': 'vancomycin', 'start': 831, 'end': 841}
# {'entity_group': 'treatment', 'score': 0.97640026, 'word': 'levaquin', 'start': 842, 'end': 850}
# {'entity_group': 'test', 'score': 0.60765773, 'word': 'flagyl', 'start': 851, 'end': 857}
# {'entity_group': 'problem', 'score': 0.6131284, 'word': 'aspiration', 'start': 867, 'end': 877}
# {'entity_group': 'test', 'score': 0.6510823, 'word': 'pna', 'start': 878, 'end': 881}
# {'entity_group': 'test', 'score': 0.9949104, 'word': 'cxr', 'start': 891, 'end': 894}
# {'entity_group': 'problem', 'score': 0.98489153, 'word': 'clear consolidation', 'start': 902, 'end': 921}
# {'entity_group': 'test', 'score': 0.87213403, 'word': 'ua', 'start': 922, 'end': 924}
# {'entity_group': 'test', 'score': 0.9882108, 'word': 'ekg', 'start': 939, 'end': 942}
# {'entity_group': 'problem', 'score': 0.66222113, 'word': 'sr', 'start': 957, 'end': 959}
# {'entity_group': 'test', 'score': 0.7554831, 'word': 'hr', 'start': 960, 'end': 962}
# {'entity_group': 'test', 'score': 0.57123077, 'word': 'na', 'start': 966, 'end': 968}
# {'entity_group': 'problem', 'score': 0.34124196, 'word': 'loss', 'start': 969, 'end': 973}
# {'entity_group': 'test', 'score': 0.8780328, 'word': 'rw', 'start': 974, 'end': 976}
# {'entity_group': 'treatment', 'score': 0.56248087, 'word': 'inferior lead v1 v2 ste v2', 'start': 977, 'end': 1003}
# {'entity_group': 'test', 'score': 0.5051142, 'word': 'overall', 'start': 1004, 'end': 1011}
# {'entity_group': 'test', 'score': 0.65750945, 'word': 'low', 'start': 1012, 'end': 1015}
# {'entity_group': 'test', 'score': 0.39072767, 'word': 'voltage', 'start': 1016, 'end': 1023}
# {'entity_group': 'test', 'score': 0.43462533, 'word': 'ce', 'start': 1024, 'end': 1026}
# {'entity_group': 'test', 'score': 0.72750664, 'word': 'significant trop', 'start': 1027, 'end': 1043}
# {'entity_group': 'test', 'score': 0.95263237, 'word': 'ck', 'start': 1049, 'end': 1051}
# {'entity_group': 'test', 'score': 0.47860584, 'word': 'flat', 'start': 1059, 'end': 1063}
# {'entity_group': 'test', 'score': 0.7133713, 'word': 'cardiology', 'start': 1064, 'end': 1074}
# {'entity_group': 'test', 'score': 0.9078973, 'word': 'ekg', 'start': 1082, 'end': 1085}
# {'entity_group': 'test', 'score': 0.7438421, 'word': 'faxed assessment', 'start': 1086, 'end': 1102}
# {'entity_group': 'test', 'score': 0.6110252, 'word': 'ce leak', 'start': 1103, 'end': 1110}
# {'entity_group': 'test', 'score': 0.43065575, 'word': 'ekg', 'start': 1125, 'end': 1128}
# {'entity_group': 'treatment', 'score': 0.31190744, 'word': 'new', 'start': 1129, 'end': 1132}
# {'entity_group': 'problem', 'score': 0.45354363, 'word': 'anteroseptal', 'start': 1133, 'end': 1145}
# {'entity_group': 'problem', 'score': 0.9839123, 'word': 'clear ischemic change', 'start': 1156, 'end': 1177}
# {'entity_group': 'test', 'score': 0.53070563, 'word': 'serial', 'start': 1200, 'end': 1206}
# {'entity_group': 'test', 'score': 0.55727285, 'word': 'ekgs', 'start': 1207, 'end': 1211}
# {'entity_group': 'test', 'score': 0.8088948, 'word': 'cycle', 'start': 1212, 'end': 1217}
# {'entity_group': 'test', 'score': 0.88793963, 'word': 'ces', 'start': 1218, 'end': 1221}
# {'entity_group': 'test', 'score': 0.88335425, 'word': 'serial ekg', 'start': 1222, 'end': 1232}
# {'entity_group': 'problem', 'score': 0.90704864, 'word': 'change', 'start': 1240, 'end': 1246}
# {'entity_group': 'problem', 'score': 0.9225411, 'word': 'schizophrenia', 'start': 1268, 'end': 1281}
# {'entity_group': 'test', 'score': 0.69107544, 'word': 'aaox1', 'start': 1303, 'end': 1308}
# {'entity_group': 'problem', 'score': 0.60411346, 'word': 'verbally', 'start': 1309, 'end': 1317}
# {'entity_group': 'problem', 'score': 0.8397068, 'word': 'depression', 'start': 1326, 'end': 1336}
# {'entity_group': 'problem', 'score': 0.5745781, 'word': 'htn', 'start': 1337, 'end': 1340}
# {'entity_group': 'problem', 'score': 0.9903808, 'word': 'dementia', 'start': 1341, 'end': 1349}
# {'entity_group': 'problem', 'score': 0.89308596, 'word': 'r eye cataract', 'start': 1350, 'end': 1364}
# {'entity_group': 'treatment', 'score': 0.7284065, 'word': 'cad', 'start': 1365, 'end': 1368}
# {'entity_group': 'treatment', 'score': 0.5826152, 'word': 'sternotomy', 'start': 1369, 'end': 1379}
# {'entity_group': 'test', 'score': 0.59222937, 'word': 'cabg', 'start': 1388, 'end': 1392}
# {'entity_group': 'problem', 'score': 0.81623065, 'word': 'desaturation', 'start': 1464, 'end': 1476}
# {'entity_group': 'problem', 'score': 0.918671, 'word': 'air hypotension', 'start': 1492, 'end': 1507}
# {'entity_group': 'problem', 'score': 0.60918695, 'word': 'well decreased', 'start': 1508, 'end': 1522}
# {'entity_group': 'problem', 'score': 0.663702, 'word': 'intake', 'start': 1528, 'end': 1534}
# {'entity_group': 'problem', 'score': 0.7235161, 'word': 'hypotensive hypoxic elevated white count', 'start': 1553, 'end': 1593}
# {'entity_group': 'problem', 'score': 0.71719533, 'word': 'work', 'start': 1605, 'end': 1609}
# {'entity_group': 'problem', 'score': 0.69585496, 'word': 'unrevealing', 'start': 1610, 'end': 1621}
# {'entity_group': 'test', 'score': 0.9887882, 'word': 'urinanalysis', 'start': 1622, 'end': 1634}
# {'entity_group': 'problem', 'score': 0.95764375, 'word': 'various pressure sore appear', 'start': 1644, 'end': 1672}
# {'entity_group': 'problem', 'score': 0.9861064, 'word': 'infected', 'start': 1673, 'end': 1681}
# {'entity_group': 'test', 'score': 0.70160025, 'word': 'chest x', 'start': 1682, 'end': 1689}
# {'entity_group': 'test', 'score': 0.63832736, 'word': 'ray', 'start': 1690, 'end': 1693}
# {'entity_group': 'problem', 'score': 0.99150693, 'word': 'acute infection', 'start': 1713, 'end': 1728}
# {'entity_group': 'problem', 'score': 0.9957844, 'word': 'severely dehydrated', 'start': 1738, 'end': 1757}
# {'entity_group': 'test', 'score': 0.8306475, 'word': 'exam', 'start': 1758, 'end': 1762}
# {'entity_group': 'treatment', 'score': 0.9814764, 'word': 'intravenous fluid', 'start': 1780, 'end': 1797}
# {'entity_group': 'test', 'score': 0.42796645, 'word': 'hydration', 'start': 1808, 'end': 1817}
# {'entity_group': 'problem', 'score': 0.99453825, 'word': 'hypotension', 'start': 1823, 'end': 1834}
# {'entity_group': 'treatment', 'score': 0.99740785, 'word': 'antibiotic', 'start': 1849, 'end': 1859}
# {'entity_group': 'problem', 'score': 0.9969214, 'word': 'diarrhea', 'start': 1876, 'end': 1884}
# {'entity_group': 'treatment', 'score': 0.8833683, 'word': 'recent antibiotic', 'start': 1885, 'end': 1902}
# {'entity_group': 'problem', 'score': 0.9195033, 'word': 'elevated', 'start': 1934, 'end': 1942}
# {'entity_group': 'test', 'score': 0.9357946, 'word': 'white count', 'start': 1943, 'end': 1954}
# {'entity_group': 'treatment', 'score': 0.9638053, 'word': 'fluconazole', 'start': 1978, 'end': 1989}
# {'entity_group': 'test', 'score': 0.81595314, 'word': 'oral', 'start': 1990, 'end': 1994}
# {'entity_group': 'test', 'score': 0.4172278, 'word': 'thrush', 'start': 1995, 'end': 2001}
# {'entity_group': 'test', 'score': 0.5558627, 'word': 'resolve', 'start': 2002, 'end': 2009}
# {'entity_group': 'test', 'score': 0.6185415, 'word': 'oral', 'start': 2010, 'end': 2014}
# {'entity_group': 'test', 'score': 0.8505247, 'word': 'nystatin', 'start': 2015, 'end': 2023}
# {'entity_group': 'test', 'score': 0.66578263, 'word': 'patient', 'start': 2024, 'end': 2031}
# {'entity_group': 'test', 'score': 0.72362256, 'word': 'x - ray', 'start': 2032, 'end': 2037}
# {'entity_group': 'test', 'score': 0.6992985, 'word': 'ankle evaluate', 'start': 2038, 'end': 2052}
# {'entity_group': 'problem', 'score': 0.8944181, 'word': 'osteomyelitis', 'start': 2053, 'end': 2066}
# {'entity_group': 'test', 'score': 0.91163397, 'word': 'underlying', 'start': 2067, 'end': 2077}
# {'entity_group': 'problem', 'score': 0.8683577, 'word': 'ulcer', 'start': 2078, 'end': 2083}
# {'entity_group': 'test', 'score': 0.90402824, 'word': 'xray', 'start': 2084, 'end': 2088}
# {'entity_group': 'problem', 'score': 0.4937537, 'word': 'consistent', 'start': 2096, 'end': 2106}
# {'entity_group': 'problem', 'score': 0.6017585, 'word': 'osteomyelitis', 'start': 2107, 'end': 2120}
# {'entity_group': 'treatment', 'score': 0.6574631, 'word': 'ng tube placed', 'start': 2129, 'end': 2143}
# {'entity_group': 'treatment', 'score': 0.9353871, 'word': 'additional nutritional support', 'start': 2144, 'end': 2174}
# {'entity_group': 'treatment', 'score': 0.98743147, 'word': 'tube feed', 'start': 2193, 'end': 2202}
# {'entity_group': 'treatment', 'score': 0.7256447, 'word': 'softs mouth prior discharge', 'start': 2223, 'end': 2250}
# {'entity_group': 'treatment', 'score': 0.97930396, 'word': 'ng tube', 'start': 2251, 'end': 2258}

# %% [markdown]
# ### Modello Biomedical NER

# %%
tokenizer3 = AutoTokenizer.from_pretrained("d4data/biomedical-ner-all")
model3 = AutoModelForTokenClassification.from_pretrained("d4data/biomedical-ner-all")
pipe3 = pipeline("ner", tokenizer=tokenizer3, model=model3, aggregation_strategy='first')

# %%
ner3 = pipe3(data['TEXT'][0])

for entity3 in ner3:
    print(entity3)
# Out:
# {'entity_group': 'Sign_symptom', 'score': 0.60468596, 'word': 'hypoxia', 'start': 293, 'end': 300}
# {'entity_group': 'Therapeutic_procedure', 'score': 0.9680628, 'word': 'dobhoff tube', 'start': 353, 'end': 365}
# {'entity_group': 'Therapeutic_procedure', 'score': 0.7064111, 'word': 'arterial line', 'start': 379, 'end': 392}
# {'entity_group': 'Lab_value', 'score': 0.9593899, 'word': '77', 'start': 422, 'end': 424}
# {'entity_group': 'Sign_symptom', 'score': 0.73298556, 'word': 'dementia p / w', 'start': 471, 'end': 483}
# {'entity_group': 'Sign_symptom', 'score': 0.9201439, 'word': 'hypoxia', 'start': 484, 'end': 491}
# {'entity_group': 'Disease_disorder', 'score': 0.94587755, 'word': 'ftt', 'start': 496, 'end': 499}
# {'entity_group': 'Disease_disorder', 'score': 0.99389136, 'word': 'pt', 'start': 538, 'end': 540}
# {'entity_group': 'Sign_symptom', 'score': 0.99994147, 'word': 'desaturation', 'start': 559, 'end': 571}
# {'entity_group': 'Lab_value', 'score': 0.8939878, 'word': "mid 80 ' s", 'start': 575, 'end': 583}
# {'entity_group': 'Disease_disorder', 'score': 0.8388552, 'word': 'ra', 'start': 587, 'end': 589}
# {'entity_group': 'Lab_value', 'score': 0.9975374, 'word': '91 %', 'start': 622, 'end': 625}
# {'entity_group': 'Detailed_description', 'score': 0.9981974, 'word': '2l', 'start': 629, 'end': 631}
# {'entity_group': 'Lab_value', 'score': 0.9391727, 'word': 'decreased', 'start': 662, 'end': 671}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.5737642, 'word': 'po', 'start': 672, 'end': 674}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.5338984, 'word': 'eating', 'start': 683, 'end': 689}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.6388951, 'word': 'ivf', 'start': 737, 'end': 740}
# {'entity_group': 'Therapeutic_procedure', 'score': 0.6403749, 'word': 'fluids', 'start': 741, 'end': 747}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.89144474, 'word': 'cxr', 'start': 760, 'end': 763}
# {'entity_group': 'Medication', 'score': 0.9753517, 'word': 'levaquin', 'start': 794, 'end': 802}
# {'entity_group': 'Dosage', 'score': 0.86456156, 'word': '500 mg', 'start': 803, 'end': 809}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.7846129, 'word': 'po', 'start': 810, 'end': 812}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.4841256, 'word': 'ctx', 'start': 849, 'end': 852}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.8695581, 'word': 'ucx', 'start': 868, 'end': 871}
# {'entity_group': 'Sign_symptom', 'score': 0.90462106, 'word': 'hypotensive', 'start': 932, 'end': 943}
# {'entity_group': 'Clinical_event', 'score': 0.99865735, 'word': 'transferred', 'start': 964, 'end': 975}
# {'entity_group': 'Disease_disorder', 'score': 0.66271573, 'word': 'pt', 'start': 1030, 'end': 1032}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.78354645, 'word': 'pt', 'start': 1062, 'end': 1064}
# {'entity_group': 'Sign_symptom', 'score': 0.99256694, 'word': 'nod', 'start': 1077, 'end': 1080}
# {'entity_group': 'Lab_value', 'score': 0.99909616, 'word': 'yes', 'start': 1081, 'end': 1084}
# {'entity_group': 'Lab_value', 'score': 0.9562146, 'word': 'no', 'start': 1088, 'end': 1090}
# {'entity_group': 'Nonbiological_location', 'score': 0.99861884, 'word': 'icu', 'start': 1210, 'end': 1213}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9995504, 'word': 'bp', 'start': 1247, 'end': 1249}
# {'entity_group': 'Therapeutic_procedure', 'score': 0.9867512, 'word': 'foley', 'start': 1349, 'end': 1354}
# {'entity_group': 'Lab_value', 'score': 0.8063843, 'word': '225cc', 'start': 1388, 'end': 1393}
# {'entity_group': 'Disease_disorder', 'score': 0.63333184, 'word': 'pt', 'start': 1395, 'end': 1397}
# {'entity_group': 'Medication', 'score': 0.85026395, 'word': 'levaquin', 'start': 1427, 'end': 1435}
# {'entity_group': 'Medication', 'score': 0.95664155, 'word': 'flagyl', 'start': 1440, 'end': 1446}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9783625, 'word': 'pna', 'start': 1471, 'end': 1474}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.85702276, 'word': 'cxr', 'start': 1484, 'end': 1487}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.99947613, 'word': 'ekg', 'start': 1552, 'end': 1555}
# {'entity_group': 'Lab_value', 'score': 0.7680252, 'word': 'loss', 'start': 1592, 'end': 1596}
# {'entity_group': 'Detailed_description', 'score': 0.99782974, 'word': 'inferior', 'start': 1606, 'end': 1614}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9423996, 'word': 'ste', 'start': 1633, 'end': 1636}
# {'entity_group': 'Lab_value', 'score': 0.63231885, 'word': 'low', 'start': 1656, 'end': 1659}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.8721554, 'word': 'ce', 'start': 1669, 'end': 1671}
# {'entity_group': 'Lab_value', 'score': 0.9885484, 'word': 'significant', 'start': 1677, 'end': 1688}

# %%
ner3 = pipe3(data['LEMMATIZED TEXT'][0])

for entity3 in ner3:
    print(entity3)
# Out:
# {'entity_group': 'Sign_symptom', 'score': 0.99497956, 'word': 'hypotension', 'start': 16, 'end': 27}
# {'entity_group': 'Sign_symptom', 'score': 0.9903528, 'word': 'hypoxia', 'start': 28, 'end': 35}
# {'entity_group': 'Therapeutic_procedure', 'score': 0.932977, 'word': 'surgical invasive procedure', 'start': 42, 'end': 69}
# {'entity_group': 'Therapeutic_procedure', 'score': 0.84485596, 'word': 'dobhoff tube placement', 'start': 80, 'end': 102}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.67839265, 'word': 'arterial line', 'start': 103, 'end': 116}
# {'entity_group': 'Disease_disorder', 'score': 0.81617785, 'word': 'present', 'start': 125, 'end': 132}
# {'entity_group': 'Disease_disorder', 'score': 0.7580083, 'word': 'illness', 'start': 133, 'end': 140}
# {'entity_group': 'Lab_value', 'score': 0.6949835, 'word': '77 yo', 'start': 141, 'end': 146}
# {'entity_group': 'Other_event', 'score': 0.2011465, 'word': 'nh', 'start': 147, 'end': 149}
# {'entity_group': 'Detailed_description', 'score': 0.3853802, 'word': 'resident', 'start': 150, 'end': 158}
# {'entity_group': 'Sign_symptom', 'score': 0.6064573, 'word': 'h / o', 'start': 159, 'end': 162}
# {'entity_group': 'Disease_disorder', 'score': 0.97565836, 'word': 'schizophrenia', 'start': 163, 'end': 176}
# {'entity_group': 'Disease_disorder', 'score': 0.9430995, 'word': 'cad', 'start': 177, 'end': 180}
# {'entity_group': 'Disease_disorder', 'score': 0.98954695, 'word': 'htn', 'start': 181, 'end': 184}
# {'entity_group': 'Disease_disorder', 'score': 0.89489883, 'word': 'dementia', 'start': 185, 'end': 193}
# {'entity_group': 'Sign_symptom', 'score': 0.8911968, 'word': 'p / w', 'start': 194, 'end': 197}
# {'entity_group': 'Sign_symptom', 'score': 0.99938905, 'word': 'hypoxia', 'start': 198, 'end': 205}
# {'entity_group': 'Disease_disorder', 'score': 0.9975383, 'word': 'ftt', 'start': 206, 'end': 209}
# {'entity_group': 'Disease_disorder', 'score': 0.9158019, 'word': 'nh', 'start': 210, 'end': 212}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.98498046, 'word': 'pt', 'start': 233, 'end': 235}
# {'entity_group': 'Sign_symptom', 'score': 0.9996474, 'word': 'desaturation', 'start': 244, 'end': 256}
# {'entity_group': 'Lab_value', 'score': 0.8216767, 'word': "80 ' s", 'start': 261, 'end': 266}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.48114753, 'word': 'ra', 'start': 267, 'end': 269}
# {'entity_group': 'Date', 'score': 0.548817, 'word': 'several', 'start': 270, 'end': 277}
# {'entity_group': 'Time', 'score': 0.8181647, 'word': 'day ago', 'start': 278, 'end': 285}
# {'entity_group': 'Lab_value', 'score': 0.17725341, 'word': 'came', 'start': 286, 'end': 290}
# {'entity_group': 'Lab_value', 'score': 0.99876845, 'word': '91 2l', 'start': 291, 'end': 296}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.89003164, 'word': 'nc', 'start': 297, 'end': 299}
# {'entity_group': 'Lab_value', 'score': 0.9990299, 'word': 'decreased', 'start': 311, 'end': 320}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9977876, 'word': 'po', 'start': 321, 'end': 323}
# {'entity_group': 'Therapeutic_procedure', 'score': 0.975329, 'word': 'eating assistance', 'start': 331, 'end': 348}
# {'entity_group': 'Detailed_description', 'score': 0.86990637, 'word': 'preferred', 'start': 349, 'end': 358}
# {'entity_group': 'Therapeutic_procedure', 'score': 0.93997514, 'word': 'food', 'start': 359, 'end': 363}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.5110807, 'word': 'ivf', 'start': 364, 'end': 367}
# {'entity_group': 'Medication', 'score': 0.5685368, 'word': 'fluid', 'start': 368, 'end': 373}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.98420584, 'word': 'cxr', 'start': 380, 'end': 383}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.8941554, 'word': 'nh', 'start': 384, 'end': 386}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.96192163, 'word': 'neg', 'start': 387, 'end': 390}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.93929553, 'word': 'ua', 'start': 391, 'end': 393}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9533978, 'word': 'po', 'start': 394, 'end': 396}
# {'entity_group': 'Medication', 'score': 0.6563579, 'word': 'levaquin', 'start': 405, 'end': 413}
# {'entity_group': 'Dosage', 'score': 0.99590254, 'word': '500 mg', 'start': 414, 'end': 420}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.77447796, 'word': 'po', 'start': 421, 'end': 423}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.8065589, 'word': '2', 'start': 424, 'end': 425}
# {'entity_group': 'Medication', 'score': 0.5339334, 'word': '-', 'start': 425, 'end': 426}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.51898134, 'word': '29', 'start': 426, 'end': 428}
# {'entity_group': 'Dosage', 'score': 0.9751494, 'word': '1 dose', 'start': 440, 'end': 446}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.97929, 'word': 'ctx', 'start': 447, 'end': 450}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.92975205, 'word': 'ucx', 'start': 464, 'end': 467}
# {'entity_group': 'Lab_value', 'score': 0.86409175, 'word': '10, 000 organism', 'start': 478, 'end': 493}
# {'entity_group': 'Sign_symptom', 'score': 0.9993036, 'word': 'hypotensive hypoxic', 'start': 512, 'end': 531}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9781527, 'word': 'hospital1', 'start': 544, 'end': 553}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.8501789, 'word': '18', 'start': 554, 'end': 556}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.6535097, 'word': 'according', 'start': 557, 'end': 566}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.8149062, 'word': 'nh note', 'start': 567, 'end': 574}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9978027, 'word': 'pt', 'start': 575, 'end': 577}
# {'entity_group': 'Detailed_description', 'score': 0.99800664, 'word': 'non', 'start': 585, 'end': 588}
# {'entity_group': 'Detailed_description', 'score': 0.3511687, 'word': 'verbal', 'start': 589, 'end': 595}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9858209, 'word': 'aaox1', 'start': 596, 'end': 601}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.99738926, 'word': 'pt', 'start': 602, 'end': 604}
# {'entity_group': 'Detailed_description', 'score': 0.77680683, 'word': 'able', 'start': 605, 'end': 609}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.980528, 'word': 'nod', 'start': 610, 'end': 613}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.98669016, 'word': 'yes', 'start': 614, 'end': 617}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.99390197, 'word': 'ed', 'start': 618, 'end': 620}
# {'entity_group': 'Sign_symptom', 'score': 0.99956244, 'word': 'cough', 'start': 628, 'end': 633}
# {'entity_group': 'Sign_symptom', 'score': 0.9999089, 'word': 'diarrhea', 'start': 634, 'end': 642}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.890148, 'word': 'sob', 'start': 643, 'end': 646}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9928376, 'word': 'dizziness', 'start': 647, 'end': 656}
# {'entity_group': 'Detailed_description', 'score': 0.9572753, 'word': 'unreponsive', 'start': 657, 'end': 668}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.987097, 'word': 'question evaluation', 'start': 669, 'end': 688}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9790086, 'word': 'icu', 'start': 689, 'end': 692}
# {'entity_group': 'Lab_value', 'score': 0.934366, 'word': 'unresponsive', 'start': 693, 'end': 705}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.99956924, 'word': 'ed', 'start': 706, 'end': 708}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9998895, 'word': 'bp', 'start': 709, 'end': 711}
# {'entity_group': 'Lab_value', 'score': 0.9995082, 'word': '85 / 65', 'start': 712, 'end': 717}
# {'entity_group': 'Lab_value', 'score': 0.99931073, 'word': '73 / 54 vs', 'start': 728, 'end': 736}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9994618, 'word': 'hr', 'start': 737, 'end': 739}
# {'entity_group': 'Lab_value', 'score': 0.98755324, 'word': '61', 'start': 740, 'end': 742}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.99979943, 'word': 'rr', 'start': 743, 'end': 745}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.46585304, 'word': '22', 'start': 746, 'end': 748}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9969869, 'word': 'o2sat', 'start': 749, 'end': 754}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9595969, 'word': '100', 'start': 755, 'end': 758}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9991592, 'word': 'nrb', 'start': 759, 'end': 762}
# {'entity_group': 'Lab_value', 'score': 0.76962847, 'word': 'total', 'start': 772, 'end': 777}
# {'entity_group': 'Lab_value', 'score': 0.9990905, 'word': '2. 9l', 'start': 778, 'end': 782}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.984721, 'word': 'foley', 'start': 783, 'end': 788}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.98641914, 'word': 'urinated', 'start': 796, 'end': 804}
# {'entity_group': 'Lab_value', 'score': 0.99895275, 'word': '225cc', 'start': 805, 'end': 810}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9957848, 'word': 'pt', 'start': 811, 'end': 813}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9837292, 'word': 'empiric', 'start': 823, 'end': 830}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.99953866, 'word': 'vancomycin', 'start': 831, 'end': 841}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.8471501, 'word': 'levaquin flagyl possible', 'start': 842, 'end': 866}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.37464747, 'word': 'aspiration', 'start': 867, 'end': 877}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.99854624, 'word': 'pna', 'start': 878, 'end': 881}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9993963, 'word': 'cxr', 'start': 891, 'end': 894}
# {'entity_group': 'Sign_symptom', 'score': 0.99291813, 'word': 'clear consolidation', 'start': 902, 'end': 921}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.58706474, 'word': 'ua', 'start': 922, 'end': 924}
# {'entity_group': 'Lab_value', 'score': 0.9994686, 'word': 'negative', 'start': 930, 'end': 938}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9999162, 'word': 'ekg', 'start': 939, 'end': 942}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9996538, 'word': 'sr', 'start': 957, 'end': 959}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.610899, 'word': 'hr', 'start': 960, 'end': 962}
# {'entity_group': 'Lab_value', 'score': 0.99302316, 'word': '80', 'start': 963, 'end': 965}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.80613464, 'word': 'na', 'start': 966, 'end': 968}
# {'entity_group': 'Sign_symptom', 'score': 0.4356813, 'word': 'loss', 'start': 969, 'end': 973}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9563595, 'word': 'rw', 'start': 974, 'end': 976}
# {'entity_group': 'Detailed_description', 'score': 0.719133, 'word': 'inferior', 'start': 977, 'end': 985}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.97335094, 'word': 'lead v1 v2', 'start': 986, 'end': 996}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9366863, 'word': 'ste v2', 'start': 997, 'end': 1003}
# {'entity_group': 'Lab_value', 'score': 0.7586898, 'word': 'low voltage', 'start': 1012, 'end': 1023}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9959772, 'word': 'ce', 'start': 1024, 'end': 1026}
# {'entity_group': 'Lab_value', 'score': 0.8463514, 'word': 'significant trop', 'start': 1027, 'end': 1043}
# {'entity_group': 'Lab_value', 'score': 0.9976172, 'word': '0. 14', 'start': 1044, 'end': 1048}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.99550843, 'word': 'ck', 'start': 1049, 'end': 1051}
# {'entity_group': 'Lab_value', 'score': 0.9893496, 'word': '596 mb', 'start': 1052, 'end': 1058}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.8991498, 'word': 'flat cardiology', 'start': 1059, 'end': 1074}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9939611, 'word': 'ekg', 'start': 1082, 'end': 1085}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9323053, 'word': 'ce', 'start': 1103, 'end': 1105}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9989974, 'word': 'ekg', 'start': 1125, 'end': 1128}
# {'entity_group': 'Lab_value', 'score': 0.50134116, 'word': 'new', 'start': 1129, 'end': 1132}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9832444, 'word': "anteroseptal q ' s", 'start': 1133, 'end': 1150}
# {'entity_group': 'Lab_value', 'score': 0.5516475, 'word': '2133', 'start': 1151, 'end': 1155}
# {'entity_group': 'Lab_value', 'score': 0.6001427, 'word': 'clear', 'start': 1156, 'end': 1161}
# {'entity_group': 'Sign_symptom', 'score': 0.8664981, 'word': 'ischemic change', 'start': 1162, 'end': 1177}
# {'entity_group': 'Detailed_description', 'score': 0.9979418, 'word': 'serial', 'start': 1200, 'end': 1206}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9993568, 'word': 'ekgs', 'start': 1207, 'end': 1211}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.99283856, 'word': 'ces', 'start': 1218, 'end': 1221}
# {'entity_group': 'Detailed_description', 'score': 0.89225703, 'word': 'serial', 'start': 1222, 'end': 1228}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.99882275, 'word': 'ekg', 'start': 1229, 'end': 1232}
# {'entity_group': 'Lab_value', 'score': 0.8696884, 'word': 'showed', 'start': 1233, 'end': 1239}
# {'entity_group': 'Lab_value', 'score': 0.93679273, 'word': 'change', 'start': 1240, 'end': 1246}
# {'entity_group': 'Sign_symptom', 'score': 0.9759251, 'word': 'schizophrenia', 'start': 1268, 'end': 1281}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.46004337, 'word': 'nh note', 'start': 1286, 'end': 1293}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9229352, 'word': 'aaox1', 'start': 1303, 'end': 1308}
# {'entity_group': 'Disease_disorder', 'score': 0.82639146, 'word': 'abusive', 'start': 1318, 'end': 1325}
# {'entity_group': 'Sign_symptom', 'score': 0.9126239, 'word': 'depression', 'start': 1326, 'end': 1336}
# {'entity_group': 'Disease_disorder', 'score': 0.9896007, 'word': 'htn', 'start': 1337, 'end': 1340}
# {'entity_group': 'Disease_disorder', 'score': 0.997867, 'word': 'dementia', 'start': 1341, 'end': 1349}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.8347696, 'word': 'r', 'start': 1350, 'end': 1351}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.37400326, 'word': 'eye', 'start': 1352, 'end': 1355}
# {'entity_group': 'Therapeutic_procedure', 'score': 0.7208015, 'word': 'cataract', 'start': 1356, 'end': 1364}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.7903668, 'word': 'cad sternotomy', 'start': 1365, 'end': 1379}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.99539363, 'word': 'cabg', 'start': 1388, 'end': 1392}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.4991536, 'word': 'hospital', 'start': 1413, 'end': 1421}
# {'entity_group': 'Therapeutic_procedure', 'score': 0.5926329, 'word': 'course', 'start': 1422, 'end': 1428}
# {'entity_group': 'Age', 'score': 0.92691725, 'word': '77 year old', 'start': 1429, 'end': 1440}
# {'entity_group': 'Sex', 'score': 0.9267257, 'word': 'male', 'start': 1441, 'end': 1445}
# {'entity_group': 'Therapeutic_procedure', 'score': 0.52816397, 'word': 'hospital', 'start': 1455, 'end': 1463}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.5335964, 'word': 'desaturation', 'start': 1464, 'end': 1476}
# {'entity_group': 'Detailed_description', 'score': 0.7474272, 'word': "mid - 80 ' s room", 'start': 1477, 'end': 1491}
# {'entity_group': 'Sign_symptom', 'score': 0.96489686, 'word': 'air hypotension', 'start': 1492, 'end': 1507}
# {'entity_group': 'Lab_value', 'score': 0.8504779, 'word': 'well', 'start': 1508, 'end': 1512}
# {'entity_group': 'Lab_value', 'score': 0.9943408, 'word': 'decreased', 'start': 1513, 'end': 1522}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.99163365, 'word': 'oral intake', 'start': 1523, 'end': 1534}
# {'entity_group': 'Sign_symptom', 'score': 0.9995823, 'word': 'hypotensive hypoxic', 'start': 1553, 'end': 1572}
# {'entity_group': 'Lab_value', 'score': 0.9995701, 'word': 'elevated', 'start': 1573, 'end': 1581}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9731729, 'word': 'white count', 'start': 1582, 'end': 1593}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9383859, 'word': 'infectious', 'start': 1594, 'end': 1604}
# {'entity_group': 'Sign_symptom', 'score': 0.963293, 'word': 'work', 'start': 1605, 'end': 1609}
# {'entity_group': 'Lab_value', 'score': 0.90066856, 'word': 'unrevealing', 'start': 1610, 'end': 1621}
# {'entity_group': 'Sign_symptom', 'score': 0.8339888, 'word': 'urinanalysis', 'start': 1622, 'end': 1634}
# {'entity_group': 'Lab_value', 'score': 0.9995763, 'word': 'negative', 'start': 1635, 'end': 1643}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.99020433, 'word': 'various', 'start': 1644, 'end': 1651}
# {'entity_group': 'Sign_symptom', 'score': 0.9876598, 'word': 'pressure sore', 'start': 1652, 'end': 1665}
# {'entity_group': 'Sign_symptom', 'score': 0.9420966, 'word': 'infected', 'start': 1673, 'end': 1681}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9402184, 'word': 'chest', 'start': 1682, 'end': 1687}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9752735, 'word': 'x - ray admission', 'start': 1688, 'end': 1703}
# {'entity_group': 'Lab_value', 'score': 0.9980483, 'word': 'negative', 'start': 1704, 'end': 1712}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9806294, 'word': 'acute', 'start': 1713, 'end': 1718}
# {'entity_group': 'Sign_symptom', 'score': 0.989824, 'word': 'infection', 'start': 1719, 'end': 1728}
# {'entity_group': 'Sign_symptom', 'score': 0.45841366, 'word': 'severely', 'start': 1738, 'end': 1746}
# {'entity_group': 'Sign_symptom', 'score': 0.70202845, 'word': 'dehydrated exam', 'start': 1747, 'end': 1762}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.7757467, 'word': 'intravenous fluid', 'start': 1780, 'end': 1797}
# {'entity_group': 'Lab_value', 'score': 0.9962914, 'word': 'decreased', 'start': 1798, 'end': 1807}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9696703, 'word': 'hydration', 'start': 1808, 'end': 1817}
# {'entity_group': 'Sign_symptom', 'score': 0.9998306, 'word': 'hypotension', 'start': 1823, 'end': 1834}
# {'entity_group': 'Medication', 'score': 0.9990102, 'word': 'antibiotic', 'start': 1849, 'end': 1859}
# {'entity_group': 'Sign_symptom', 'score': 0.5799814, 'word': 'diarrhea', 'start': 1876, 'end': 1884}
# {'entity_group': 'Medication', 'score': 0.9685371, 'word': 'antibiotic', 'start': 1892, 'end': 1902}
# {'entity_group': 'Therapeutic_procedure', 'score': 0.7373039, 'word': 'course', 'start': 1903, 'end': 1909}
# {'entity_group': 'Nonbiological_location', 'score': 0.9963831, 'word': 'nursing home', 'start': 1910, 'end': 1922}
# {'entity_group': 'Lab_value', 'score': 0.99985516, 'word': 'elevated', 'start': 1934, 'end': 1942}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9899018, 'word': 'white count', 'start': 1943, 'end': 1954}
# {'entity_group': 'Dosage', 'score': 0.70736015, 'word': 'one dose', 'start': 1969, 'end': 1977}
# {'entity_group': 'Medication', 'score': 0.99767095, 'word': 'fluconazole', 'start': 1978, 'end': 1989}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.6004472, 'word': 'oral', 'start': 1990, 'end': 1994}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.6373526, 'word': 'thrush resolve', 'start': 1995, 'end': 2009}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.70843095, 'word': 'oral', 'start': 2010, 'end': 2014}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.97522503, 'word': 'nystatin', 'start': 2015, 'end': 2023}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9885364, 'word': 'x - ray', 'start': 2032, 'end': 2037}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9212119, 'word': 'ankle', 'start': 2038, 'end': 2043}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.9952246, 'word': 'evaluate', 'start': 2044, 'end': 2052}
# {'entity_group': 'Disease_disorder', 'score': 0.999915, 'word': 'osteomyelitis', 'start': 2053, 'end': 2066}
# {'entity_group': 'Sign_symptom', 'score': 0.7103996, 'word': 'ulcer', 'start': 2078, 'end': 2083}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.994645, 'word': 'xray', 'start': 2084, 'end': 2088}
# {'entity_group': 'Lab_value', 'score': 0.7680981, 'word': 'consistent', 'start': 2096, 'end': 2106}
# {'entity_group': 'Disease_disorder', 'score': 0.99991155, 'word': 'osteomyelitis', 'start': 2107, 'end': 2120}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.47546387, 'word': 'ng', 'start': 2129, 'end': 2131}
# {'entity_group': 'Therapeutic_procedure', 'score': 0.4973207, 'word': 'tube', 'start': 2132, 'end': 2136}
# {'entity_group': 'Therapeutic_procedure', 'score': 0.8780989, 'word': 'additional nutritional support', 'start': 2144, 'end': 2174}
# {'entity_group': 'Therapeutic_procedure', 'score': 0.48917073, 'word': 'hospital', 'start': 2175, 'end': 2183}
# {'entity_group': 'Detailed_description', 'score': 0.839424, 'word': 'tube feed', 'start': 2193, 'end': 2202}
# {'entity_group': 'Therapeutic_procedure', 'score': 0.80528873, 'word': 'hospital tolerating softs', 'start': 2203, 'end': 2228}
# {'entity_group': 'Clinical_event', 'score': 0.53289276, 'word': 'discharge', 'start': 2241, 'end': 2250}
# {'entity_group': 'Diagnostic_procedure', 'score': 0.77478456, 'word': 'ng tube', 'start': 2251, 'end': 2258}
# {'entity_group': 'Clinical_event', 'score': 0.96541405, 'word': 'discharge', 'start': 2278, 'end': 2287}

# %% [markdown]
# ## Modello MedCAT

# %% [markdown]
# ### Modelli clinici richiesti da MedCAT

# %%
DATA_DIR = "./data/"
vocab_path = DATA_DIR + "vocab.dat"
cdb_path = DATA_DIR + "cdb-medmen.dat"

# %% [markdown]
# ### Caricamento dei modelli

# %%
# Create and load the CDB (Concept Database)
cdb = CDB.load(cdb_path)

# Create and load the Vocabulary
vocab = Vocab.load(vocab_path)

# Load model for MetaAnnotations (optional)
mc_status = MetaCAT.load("./data/Status/")

# %% [markdown]
# ### Creazione del Medical Concept Annotation Tool (CAT)

# %%
# Create CAT - the main class from medcat used for concept annotation
cat = CAT(cdb=cdb, config=cdb.config, vocab=vocab, meta_cats=[mc_status])

# %% [markdown]
# ### Seleziono solo le entità di interesse

# %%
# Detect only the following entity:
    # bpoc|T023|Body Part, Organ, or Organ Component
    # lbtr|T034|Laboratory or Test Result
    # patf|T046|Pathologic Function
    # dsyn|T047|Disease or Syndrome
    # mobd|T048|Mental or Behavioral Dysfunction
    # lbpr|T059|Laboratory Procedure
    # diap|T060|Diagnostic Procedure
    # topp|T061|Therapeutic or Preventive Procedure
    # phsu|T121|Pharmacologic Substance ---> SE LO AGGIUNGO MI METTE ANCHE ALTRA ROBA TIPO VITAMINE, ENZIMI, ETC.
    # sosy|T184|Sign or Symptom

type_ids_filter = ['T023', 'T034', 'T046', 'T047', 'T048', 'T059', 'T060', 'T061', 'T121', 'T184']
cui_filters = set()
for type_ids in type_ids_filter:
    cui_filters.update(cat.cdb.addl_info['type_id2cuis'][type_ids])
cat.cdb.config.linking['filters']['cuis'] = cui_filters

# %%
color_dict = {
    'Body Part, Organ, or Organ Component': '#FFCE80',  # Arancione pastello
    'Laboratory or Test Result': '#FFF9C4',             # Giallo chiaro
    'Disease or Syndrome': '#B5EAD7',                   # Verde acqua chiaro
    'Mental or Behavioral Dysfunction': '#F0B2FF',      # Viola pastello
    'Laboratory Procedure': '#D0D9FF',                  # Blu chiaro
    'Diagnostic Procedure': '#FFD9EC',                  # Rosa chiaro
    'Therapeutic or Preventive Procedure': '#C4FFFF',   # Azzurro chiaro
    'Pharmacologic Substance': '#FFDAB9',               # Pesca pastello
    'Sign or Symptom': '#FFC4F3',                       # Magenta chiaro
    'Pathologic Function': '#B5EAD7'                    # Verde acqua chiaro
}

# %% [markdown]
# ### Annotazione su testo NON preprocessato

# %%
entities = cat.get_entities(data['TEXT'][0])

extracted_data = []
# Extract 'pretty_name' and 'types' values from the dictionary
for key, value in entities['entities'].items():
    if value['meta_anns']['Status']['value'] == 'Affirmed':
        if value['types'][0] == 'Pharmacologic Substance':
            extracted_data.append((value['source_value'], value['types'][0]))
        else:
            extracted_data.append((value['pretty_name'], value['types'][0]))

# Create a dataframe
df = pd.DataFrame(extracted_data, columns=['Nome', 'Entità'])
print(df)
# Out:
#                           Nome                               Entità
# 0                     MEDICINE              Pharmacologic Substance
# 1                        DRUGS  Therapeutic or Preventive Procedure
# 2                      Hypoxia                  Pathologic Function
# 3         procedures treatment  Therapeutic or Preventive Procedure
# 4            placement of tube  Therapeutic or Preventive Procedure
# ..                         ...                                  ...
# 126       Hypertensive disease                  Disease or Syndrome
# 127  Coronary Arteriosclerosis                  Disease or Syndrome
# 128       Hypertensive disease                  Disease or Syndrome
# 129       Hypertensive disease                  Disease or Syndrome
# 130   Cerebrovascular accident                  Disease or Syndrome
#
# [131 rows x 2 columns]

# %% [markdown]
# ### Annotazione su testo preprocessato

# %%
entities_lemma = cat.get_entities(data['LEMMATIZED TEXT'][0])

extracted_data = []
# Extract 'pretty_name' and 'types' values from the dictionary
for key, value in entities_lemma['entities'].items():
    if value['meta_anns']['Status']['value'] == 'Affirmed':
        if value['types'][0] == 'Pharmacologic Substance':
            extracted_data.append((value['source_value'], value['types'][0]))
        else:
            extracted_data.append((value['pretty_name'], value['types'][0]))

# Create a dataframe
df = pd.DataFrame(extracted_data, columns=['Nome', 'Entità'])
print(df)
# Out:
#                                      Nome  \
# 0                                 Hypoxia
# 1                    procedures treatment
# 2                       placement of tube
# 3                           Schizophrenia
# 4               Coronary Arteriosclerosis
# 5                    Hypertensive disease
# 6                                Dementia
# 7                                 Hypoxia
# 8                  Fertilization in Vitro
# 9                                 Hypoxia
# 10                              Dizziness
# 11                    Electrocardiography
# 12                    Electrocardiography
# 13                          Schizophrenia
# 14                      Mental Depression
# 15                   Hypertensive disease
# 16                               Dementia
# 17              Coronary Arteriosclerosis
# 18                 Sternotomy (procedure)
# 19         Coronary Artery Bypass Surgery
# 20                                Hypoxia
# 21            Bacterial Count Measurement
# 22                              Infection
# 23                      Plain chest X-ray
# 24                           Treated with
# 25                               Diarrhea
# 26            Bacterial Count Measurement
# 27                           Treated with
# 28               Crystallographies, X Ray
# 29                          Osteomyelitis
# 30                    Nutritional Support
# 31                    Electrocardiography
# 32                  Myocardial Infarction
# 33                    Electrocardiography
# 34                 Right atrial structure
# 35           Left Ventricular Hypertrophy
# 36  Left ventricular systolic dysfunction
# 37                           Heart Septum
# 38                 Cardiac wall structure
# 39                 Cardiac wall structure
# 40                             Dysarthria
# 41          Right temporal lobe structure
# 42              X-Ray Computed Tomography
# 43                                aspirin
# 44                                 statin
# 45                                  Brain
# 46                 Hemoglobin measurement
# 47                          Acetaminophen
# 48                                  Fever
# 49                                Aspirin
# 50                           Constipation
# 51                           Atorvastatin
# 52                             Olanzapine
#
#                                   Entità
# 0                    Pathologic Function
# 1    Therapeutic or Preventive Procedure
# 2    Therapeutic or Preventive Procedure
# 3       Mental or Behavioral Dysfunction
# 4                    Disease or Syndrome
# 5                    Disease or Syndrome
# 6       Mental or Behavioral Dysfunction
# 7                    Pathologic Function
# 8    Therapeutic or Preventive Procedure
# 9                    Pathologic Function
# 10                       Sign or Symptom
# 11                  Diagnostic Procedure
# 12                  Diagnostic Procedure
# 13      Mental or Behavioral Dysfunction
# 14      Mental or Behavioral Dysfunction
# 15                   Disease or Syndrome
# 16      Mental or Behavioral Dysfunction
# 17                   Disease or Syndrome
# 18   Therapeutic or Preventive Procedure
# 19   Therapeutic or Preventive Procedure
# 20                   Pathologic Function
# 21                  Laboratory Procedure
# 22                   Pathologic Function
# 23                  Diagnostic Procedure
# 24   Therapeutic or Preventive Procedure
# 25                       Sign or Symptom
# 26                  Laboratory Procedure
# 27   Therapeutic or Preventive Procedure
# 28                  Laboratory Procedure
# 29                   Disease or Syndrome
# 30   Therapeutic or Preventive Procedure
# 31                  Diagnostic Procedure
# 32                   Disease or Syndrome
# 33                  Diagnostic Procedure
# 34  Body Part, Organ, or Organ Component
# 35                   Disease or Syndrome
# 36                   Disease or Syndrome
# 37  Body Part, Organ, or Organ Component
# 38  Body Part, Organ, or Organ Component
# 39  Body Part, Organ, or Organ Component
# 40      Mental or Behavioral Dysfunction
# 41  Body Part, Organ, or Organ Component
# 42                  Diagnostic Procedure
# 43               Pharmacologic Substance
# 44               Pharmacologic Substance
# 45  Body Part, Organ, or Organ Component
# 46                  Laboratory Procedure
# 47               Pharmacologic Substance
# 48                       Sign or Symptom
# 49               Pharmacologic Substance
# 50                       Sign or Symptom
# 51               Pharmacologic Substance
# 52               Pharmacologic Substance

# %% [markdown]
# ### Visualizzazione testo annotato

# %%
from spacy import displacy

doc = {"text": data['LEMMATIZED TEXT'][0], "ents": [], "title": None}

for key, value in entities_lemma['entities'].items():
    if value['meta_anns']['Status']['value'] == 'Affirmed':
        ent = {
            'start': value['start'],
            'end': value['end'],
            'label': value['types'][0]
        }
        doc['ents'].append(ent)

colors = color_dict
options = {"ents": list(colors.keys()), "colors": colors}

# Call spacy.displacy.render() to visualize the entities
displacy.render(doc, style='ent', options=options, jupyter=True, manual=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Chief Complaint Hypotension/
# <mark class="entity" style="background: #B5EAD7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypoxia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Pathologic Function</span>
# </mark>
#  Major Surgical Invasive
# <mark class="entity" style="background: #C4FFFF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Procedure
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Therapeutic or Preventive Procedure</span>
# </mark>
#  Placement Dobhoff
# <mark class="entity" style="background: #C4FFFF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tube Placement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Therapeutic or Preventive Procedure</span>
# </mark>
#  Arterial line History Present Illness 77 yo NH resident h/o
# <mark class="entity" style="background: #F0B2FF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     schizophrenia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Mental or Behavioral Dysfunction</span>
# </mark>
#
# <mark class="entity" style="background: #B5EAD7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CAD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease or Syndrome</span>
# </mark>
#
# <mark class="entity" style="background: #B5EAD7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HTN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease or Syndrome</span>
# </mark>
#
# <mark class="entity" style="background: #F0B2FF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dementia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Mental or Behavioral Dysfunction</span>
# </mark>
#  p/w
# <mark class="entity" style="background: #B5EAD7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypoxia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Pathologic Function</span>
# </mark>
#  FTT NH According NH record pt episode desaturation mid 80 's RA several day ago came 91 2L NC also noted decreased po intake eating assistance preferred food
# <mark class="entity" style="background: #C4FFFF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IVF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Therapeutic or Preventive Procedure</span>
# </mark>
#  fluid given CXR NH neg UA po Started levaquin 500 mg po 2-29 also given 1 dose CTX Subsequently ucx came back 10,000 organism patient continued hypotensive
# <mark class="entity" style="background: #B5EAD7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypoxic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Pathologic Function</span>
# </mark>
#  transferred Hospital1 18 According NH note pt mostly non-verbal AAOx1 Pt able nod yes ED denied cough diarrhea SOB
# <mark class="entity" style="background: #FFC4F3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dizziness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign or Symptom</span>
# </mark>
#  unreponsive question evaluation ICU unresponsive ED BP 85/65 initially 73/54 VS HR 61 RR 22 O2Sat 100 NRB received total 2.9L foley placed urinated 225cc Pt received empiric Vancomycin Levaquin FLagyl possible aspiration PNA although CXR showed clear consolidation UA done negative EKG done revealed SR HR 80 NA loss RW inferior lead V1 V2 STE V2 overall low voltage CE significant Trop 0.14 CK 596 MB flat Cardiology called
# <mark class="entity" style="background: #FFD9EC; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ekg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic Procedure</span>
# </mark>
#  faxed assessment CE leak likely demand EKG new anteroseptal q 's 2133 clear ischemic change currently Recommended Serial EKGs cycle CEs Serial
# <mark class="entity" style="background: #FFD9EC; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EKG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Diagnostic Procedure</span>
# </mark>
#  showed change Past Medical History
# <mark class="entity" style="background: #F0B2FF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Schizophrenia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Mental or Behavioral Dysfunction</span>
# </mark>
#  per NH note baseline AAOx1 verbally abusive
# <mark class="entity" style="background: #F0B2FF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Depression
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Mental or Behavioral Dysfunction</span>
# </mark>
#
# <mark class="entity" style="background: #B5EAD7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HTN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease or Syndrome</span>
# </mark>
#
# <mark class="entity" style="background: #F0B2FF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dementia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Mental or Behavioral Dysfunction</span>
# </mark>
#  R eye cataract
# <mark class="entity" style="background: #B5EAD7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CAD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Disease or Syndrome</span>
# </mark>
#
# <mark class="entity" style="background: #C4FFFF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sternotomy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Therapeutic or Preventive Procedure</span>
# </mark>
#  present
# <mark class="entity" style="background: #C4FFFF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CABG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Therapeutic or Preventive Procedure</span>
# </mark>
#  documentation Brief Hospital Course 77 year old male admitted hospital desaturation mid-80 's room air hypotension well decreased oral intake admission patient hypotensive

# %% [markdown]
# ## Salvataggio delle entità estratte dal Preprocessed NOTEEVENTS in un file CSV

# %%
# Lista per salvare i risultati finali
risultati_finali = []

# Itera su ogni riga del dataframe 'data'
for index, row in data.iterrows():
    # Esegui le operazioni per la riga corrente

    entities_tot = cat.get_entities(row['LEMMATIZED TEXT'])
    
    extracted_data = []
    # Extract 'pretty_name' and 'types' values from the dictionary
    for key, value in entities_tot['entities'].items():
        if value['meta_anns']['Status']['value'] == 'Affirmed':
            if value['type_ids'][0] in type_ids_filter:
                if value['types'][0] == 'Pharmacologic Substance':
                    extracted_data.append((value['source_value'], value['types'][0]))
                else:
                    extracted_data.append((value['pretty_name'], value['types'][0]))

    # Create a dataframe
    df = pd.DataFrame(extracted_data, columns=['Nome', 'Entità'])

    categorie_dict = {}
    for _, val in df.iterrows():
        nome = val['Nome']
        categoria = val['Entità']
        if categoria in categorie_dict:
            categorie_dict[categoria].append(nome)
        else:
            categorie_dict[categoria] = [nome]

    lista_finale = []
    for categoria, nomi in categorie_dict.items():
        lista_finale.append((categoria, nomi))

    df_finale = pd.DataFrame(lista_finale, columns=['Categoria', 'Nomi'])
    df_finale['Nomi'] = df_finale['Nomi'].apply(lambda x: ', '.join(set(x)))
    df_finale = df_finale.pivot_table(index=None, columns='Categoria', values='Nomi', aggfunc=lambda x: x)
    df_finale.columns.name = None

    df_finale['Subject ID'] = row['SUBJECT_ID']
    df_finale['Note ID'] = row['ROW_ID']
    # Aggiungi i risultati finali alla lista
    risultati_finali.append(df_finale)

# Unisci i risultati finali in un unico dataframe
df_completo = pd.concat(risultati_finali)

# Salvataggio del dataframe merge in un file CSV
df_completo.to_csv("ner_noteevents.csv", sep=";", index=False)
